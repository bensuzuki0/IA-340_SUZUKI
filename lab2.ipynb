# %% [markdown]
# # Lab 2

# %%
import warnings
warnings.simplefilter('ignore')

import pandas as pd

df = pd.read_csv('s3://ia340suzuki/Crime_Data_from_2020_to_Present.csv') # load the data from s3
df.head(10) #show the top 10 rows
# Out:
#        DR_NO               Date Rptd                DATE OCC  TIME OCC  AREA  \
# 0  211507896  04/11/2021 12:00:00 AM  11/07/2020 12:00:00 AM       845    15
# 1  201516622  10/21/2020 12:00:00 AM  10/18/2020 12:00:00 AM      1845    15
# 2  240913563  12/10/2024 12:00:00 AM  10/30/2020 12:00:00 AM      1240     9
# 3  210704711  12/24/2020 12:00:00 AM  12/24/2020 12:00:00 AM      1310     7
# 4  201418201  10/03/2020 12:00:00 AM  09/29/2020 12:00:00 AM      1830    14
# 5  240412063  12/11/2024 12:00:00 AM  11/11/2020 12:00:00 AM      1210     4
# 6  240317069  12/16/2024 12:00:00 AM  04/16/2020 12:00:00 AM      1350     3
# 7  201115217  10/29/2020 12:00:00 AM  07/07/2020 12:00:00 AM      1400    11
# 8  241708596  04/20/2024 12:00:00 AM  03/02/2020 12:00:00 AM      1200    17
# 9  242113813  12/18/2024 12:00:00 AM  09/01/2020 12:00:00 AM       900    21
#
#      AREA NAME  Rpt Dist No  Part 1-2  Crm Cd  \
# 0  N Hollywood         1502         2     354
# ...

# %%
df.shape #show the number of rows and columns
# Out:
# (1004991, 28)

# %% [markdown]
# ## My data has 1,004,991 rows and 28 columns. Rows are text and numerical

# %%
df.sort_values(by='LOCATION')
# Out:
#             DR_NO               Date Rptd                DATE OCC  TIME OCC  \
# 514080  221421172  12/17/2022 12:00:00 AM  12/04/2022 12:00:00 AM      1200
# 559191  221416993  09/27/2022 12:00:00 AM  08/20/2022 12:00:00 AM      1500
# 432903  221409015  04/09/2022 12:00:00 AM  04/09/2022 12:00:00 AM      1930
# 17194   201420046  11/09/2020 12:00:00 AM  11/08/2020 12:00:00 AM      1930
# 617129  221414581  08/03/2022 12:00:00 AM  08/03/2022 12:00:00 AM       310
# ...           ...                     ...                     ...       ...
# 793541  231105669  02/13/2023 12:00:00 AM  02/13/2023 12:00:00 AM      1620
# 653345  231112618  08/24/2023 12:00:00 AM  08/18/2023 12:00:00 AM      1430
# 163453  201112781  08/22/2020 12:00:00 AM  08/22/2020 12:00:00 AM      1715
# 134615  201109722  05/25/2020 12:00:00 AM  05/24/2020 12:00:00 AM       745
# 597084  221109208  05/15/2022 12:00:00 AM  05/13/2022 12:00:00 AM      1430
#
# ...

# %%
#rename columns
df = df.rename(columns={"AREA NAME": "REGION"}) 
df.head()
# Out:
#        DR_NO               Date Rptd                DATE OCC  TIME OCC  AREA  \
# 0  211507896  04/11/2021 12:00:00 AM  11/07/2020 12:00:00 AM       845    15
# 1  201516622  10/21/2020 12:00:00 AM  10/18/2020 12:00:00 AM      1845    15
# 2  240913563  12/10/2024 12:00:00 AM  10/30/2020 12:00:00 AM      1240     9
# 3  210704711  12/24/2020 12:00:00 AM  12/24/2020 12:00:00 AM      1310     7
# 4  201418201  10/03/2020 12:00:00 AM  09/29/2020 12:00:00 AM      1830    14
#
#         REGION  Rpt Dist No  Part 1-2  Crm Cd  \
# 0  N Hollywood         1502         2     354
# 1  N Hollywood         1521         1     230
# 2     Van Nuys          933         2     354
# 3     Wilshire          782         1     331
# 4      Pacific         1454         1     420
#
#                                          Crm Cd Desc  ... Status  Status Desc  \
# 0                                  THEFT OF IDENTITY  ...     IC  Invest Cont
# ...

# %% [markdown]
# ### Renamed AREA NAME to REGION

# %%
df.isnull().sum() #show the number of rows containing null value
# Out:
# DR_NO                   0
# Date Rptd               0
# DATE OCC                0
# TIME OCC                0
# AREA                    0
# REGION                  0
# Rpt Dist No             0
# Part 1-2                0
# Crm Cd                  0
# Crm Cd Desc             0
# Mocodes            151619
# Vict Age                0
# Vict Sex           144644
# Vict Descent       144656
# Premis Cd              16
# Premis Desc           588
# Weapon Used Cd     677744
# Weapon Desc        677744
# Status                  1
# Status Desc             0
# Crm Cd 1               11
# Crm Cd 2           935831
# Crm Cd 3          1002677
# Crm Cd 4          1004927
# LOCATION                0
# Cross Street       850755
# LAT                     0
# LON                     0
# dtype: int64

# %%
df.dropna() #drop null values
# Out:
#             DR_NO               Date Rptd                DATE OCC  TIME OCC  \
# 27751   201904032  01/02/2020 12:00:00 AM  01/01/2020 12:00:00 AM      2135
# 134755  200613424  08/02/2020 12:00:00 AM  08/02/2020 12:00:00 AM      2030
# 363765  210617136  10/08/2021 12:00:00 AM  10/07/2021 12:00:00 AM      1950
# 372524  210209196  05/08/2021 12:00:00 AM  05/08/2021 12:00:00 AM       230
# 490101  220600626  04/27/2022 12:00:00 AM  04/23/2022 12:00:00 AM      2300
# 537834  221718232  12/25/2022 12:00:00 AM  12/25/2022 12:00:00 AM      1150
# 586003  221401314  11/10/2022 12:00:00 AM  11/10/2022 12:00:00 AM      2117
# 728576  231717599  11/15/2023 12:00:00 AM  11/15/2023 12:00:00 AM       400
# 809419  231915572  10/21/2023 12:00:00 AM  10/21/2023 12:00:00 AM         1
# 934749  241905348  02/04/2024 12:00:00 AM  02/03/2024 12:00:00 AM      1100
#
#         AREA      REGION  Rpt Dist No  Part 1-2  Crm Cd  \
# 27751     19     Mission         1924         1     761
# ...

# %% [markdown]
# #### Using dropna(), I now have 10 rows and 28 columns. Before, I had over 1 million rows.

# %%
df.isnull().sum()
# Out:
# DR_NO                   0
# Date Rptd               0
# DATE OCC                0
# TIME OCC                0
# AREA                    0
# REGION                  0
# Rpt Dist No             0
# Part 1-2                0
# Crm Cd                  0
# Crm Cd Desc             0
# Mocodes            151619
# Vict Age                0
# Vict Sex           144644
# Vict Descent       144656
# Premis Cd              16
# Premis Desc           588
# Weapon Used Cd     677744
# Weapon Desc        677744
# Status                  1
# Status Desc             0
# Crm Cd 1               11
# Crm Cd 2           935831
# Crm Cd 3          1002677
# Crm Cd 4          1004927
# LOCATION                0
# Cross Street       850755
# LAT                     0
# LON                     0
# dtype: int64

# %%
df_clean = df.dropna()

# %%
df[(df['LAT']>= 34.1)]
# Out:
#              DR_NO               Date Rptd                DATE OCC  TIME OCC  \
# 0        211507896  04/11/2021 12:00:00 AM  11/07/2020 12:00:00 AM       845
# 1        201516622  10/21/2020 12:00:00 AM  10/18/2020 12:00:00 AM      1845
# 2        240913563  12/10/2024 12:00:00 AM  10/30/2020 12:00:00 AM      1240
# 7        201115217  10/29/2020 12:00:00 AM  07/07/2020 12:00:00 AM      1400
# 8        241708596  04/20/2024 12:00:00 AM  03/02/2020 12:00:00 AM      1200
# ...            ...                     ...                     ...       ...
# 1004982  251704149  02/28/2025 12:00:00 AM  02/27/2025 12:00:00 AM      1210
# 1004985  251904120  02/12/2025 12:00:00 AM  02/12/2025 12:00:00 AM      1430
# 1004986  252104112  02/02/2025 12:00:00 AM  02/02/2025 12:00:00 AM       130
# 1004989  251704066  01/17/2025 12:00:00 AM  01/17/2025 12:00:00 AM      1600
# 1004990  251904210  03/25/2025 12:00:00 AM  03/25/2025 12:00:00 AM      1235
#
# ...

# %%
df['AREA'] #view AREA column
# Out:
# 0          15
# 1          15
# 2           9
# 3           7
# 4          14
#            ..
# 1004986    21
# 1004987     4
# 1004988    13
# 1004989    17
# 1004990    19
# Name: AREA, Length: 1004991, dtype: int64

# %% [markdown]
# # Filter data to show Latitude greater than 34.1 degrees. I also sorted data to only show AREA.

# %%
df[0:5]
# Out:
#        DR_NO               Date Rptd                DATE OCC  TIME OCC  AREA  \
# 0  211507896  04/11/2021 12:00:00 AM  11/07/2020 12:00:00 AM       845    15
# 1  201516622  10/21/2020 12:00:00 AM  10/18/2020 12:00:00 AM      1845    15
# 2  240913563  12/10/2024 12:00:00 AM  10/30/2020 12:00:00 AM      1240     9
# 3  210704711  12/24/2020 12:00:00 AM  12/24/2020 12:00:00 AM      1310     7
# 4  201418201  10/03/2020 12:00:00 AM  09/29/2020 12:00:00 AM      1830    14
#
#         REGION  Rpt Dist No  Part 1-2  Crm Cd  \
# 0  N Hollywood         1502         2     354
# 1  N Hollywood         1521         1     230
# 2     Van Nuys          933         2     354
# 3     Wilshire          782         1     331
# 4      Pacific         1454         1     420
#
#                                          Crm Cd Desc  ... Status  Status Desc  \
# 0                                  THEFT OF IDENTITY  ...     IC  Invest Cont
# ...

# %%
Crime_by_Date = df.groupby('AREA')['Crm Cd'].sum() #aggregate the total case number per day
Crime_by_Date.head()
# Out:
# AREA
# 1    34649305
# 2    23467429
# 3    29358823
# 4    18892991
# 5    21551133
# Name: Crm Cd, dtype: int64

# %%
Crime_by_Date.plot() #use a line chart to show the result
# Out:
# <Axes: xlabel='AREA'>

# %% [markdown]
# # This vizualization shows which area has the most crimes commited. The chart shows that region 1 had the most crimes.

# %%
Area_By_Region = df.groupby('REGION')['AREA'].sum()
Area_By_Region.nlargest(10).plot.bar()
# Out:
# <Axes: xlabel='REGION'>

# %% [markdown]
# # This vizualization shows which region has the most crimes. The charts shows that the Olympic region has the most crimes.
